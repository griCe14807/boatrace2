# %% [markdown]
# ## ボートレース 公式サイトからScrapeを行いpickleファイルに保存

# %%
from datetime import datetime
from datetime import timedelta
from http.client import RemoteDisconnected
from bs4 import BeautifulSoup
import urllib.request
import time
import pandas as pd
import re

# %% [markdown]
# ### web pageから情報を取ってきてpandas dfに格納するモジュール

# %%
def scrape_racelist(soup, rno, jcd, hd):
    """
    racelistのページに書かれている情報をクロール
    :return:
    """
    table = soup.find(class_="contentsFrame1_inner").find_all(class_="table1")[1]
    rows = table.find_all("tbody", {"class": "is-fs12"})
    
    race_result_dict_list = []
    
    for i, row in enumerate(rows, 1):
        race_result_dict = {"date": "-".join([hd[0:4], hd[5:7], hd[8:10]]),
                            "venue": jcd, "raceNumber": rno[:-1]
                           }
        # 枠
        race_result_dict["枠"] = i
        # racer id
        race_result_dict["racer_id"] = row.find(class_="is-fs11").text.split("\n")[1][-6:-2]

        # 選手名。最後の[1:-1]は改行を削除するため
        racer_name = row.find(class_="is-fs18 is-fBold").text[1:-1]
        
        # race_result_listの要素としてクロールした結果のリストを追加
        race_result_dict["racer_name"] = racer_name

        # racer data
        racer_column_3 = row.find_all("td", {"class": "is-lineH2"})[0].text.split("\n")
        race_result_dict["num_false_start"] = racer_column_3[1][-3:-1]
        race_result_dict["num_late_start"] = racer_column_3[2][-3:-1]

        # crawl motor data
        motor_column = row.find_all("td", {"class": " is-lineH2"})[0].text.split("\n")
        race_result_dict["motorNo"] = motor_column[1][-4:-1]
        race_result_dict["モーター2連率"] = motor_column[2][-7:-1]
        race_result_dict["モーター3連率"] = motor_column[3][-7:-1]

        # crawl boat data
        boat_column = row.find_all("td", {"class": " is-lineH2"})[1].text.split("\n")
        race_result_dict["boatNo"] = boat_column[1][-4:-1]
        race_result_dict["ボート2連率"] = boat_column[2][-7:-1]
        race_result_dict["ボート3連率"] = boat_column[3][-7:-1]
        
        race_result_dict_list.append(race_result_dict)
        
    # dictをdfに変換
    race_result_df = pd.DataFrame.from_dict(race_result_dict_list)

    time.sleep(0.1)

    return race_result_df

# %%
def scrape_beforeinfo(soup, rno, jcd, hd):
    """
    exhibitionの情報など、直前情報ページに書かれている情報をクロール
    :param soup:
    :param rno:
    :param jcd:
    :param hd:
    :return:

    # TODO: プロペラ
    # TODO: 部品交換
    # TODO: 前走成績
    # TODO: 調整重量 (adjustment weight) (kg)
    # TODO: 風向き

    """
    race_result_dict_list = []
    
    table = soup.find(class_="contentsFrame1_inner").find_all(class_="table1")[1]
    rows = table.find_all("tbody", {"class": "is-fs12"})
    
    table2 = soup.find(class_="contentsFrame1_inner").find_all(class_="table1")[2]
    rows2 = table2.find_all("tr")


    for i, (row, row2) in enumerate(zip(rows, rows2[2:]), 1):
        
        race_result_dict = {"date": "-".join([hd[0:4], hd[5:7], hd[8:10]]),
                        "venue": jcd,
                        "raceNumber": rno[:-1]
                        }
        # 枠
        race_result_dict["枠"] = i
        
        # 水面気象情報
        table3 = soup.find(class_="contentsFrame1_inner").find(class_="weather1")
        weather_data = (table3.find_all(class_="weather1_bodyUnitLabelData"))
        weather_string = table3.find_all(class_="weather1_bodyUnitLabelTitle")

        race_result_dict["temperature"] = weather_data[0].text[:-1]
        race_result_dict["weather"] = weather_string[1].text
        race_result_dict["wind_speed"] = weather_data[1].text[:-1]
        race_result_dict["water_temperature"] = weather_data[2].text[:-1]
        race_result_dict["wave_height"] = weather_data[3].text[:-2]

        # racer weight (kg)
        # 書いていないことがあり、その場合エラーになる
        race_result_dict["weight"] = row.find("td", {"rowspan": "2"}).text[:-2]

        # 展示タイム
        race_result_dict["exhibitionTime"] = row.find_all("td", {"rowspan": "4"})[3].text

        # チルト角度
        race_result_dict["tilt"] = row.find_all("td", {"rowspan": "4"})[4].text
        
        # 展示競争での進入コース
        race_result_dict["exhibition_cource"] = row2.find_all("span")[0].text
        # 展示start time (ST, flyng, late)
        ex_st_ = row2.find_all("span")[3].text
        if len(ex_st_) == 3:
            race_result_dict["exhibition_ST"] = ex_st_
            race_result_dict["flying"] = 0
            race_result_dict["late"] = 0

        elif len(ex_st_) == 4:
            race_result_dict["exhibition_ST"] = ex_st_[1:]
            if ex_st_[0] == "F":
                race_result_dict["flying"] = 1
                race_result_dict["late"] = 0
            # elif ex_st_[0] == "L":
            #     race_result_dict["late_{0}".format(i)] = 1
            else:
                raise Exception("{0}号艇ex_stが予定外（{1}）".format(i, ex_st_))
        elif len(ex_st_) == 1:
            if ex_st_[0] == "L":
                race_result_dict["exhibition_ST"] = None
                race_result_dict["late"] = 1
            else:
                raise Exception("{0}号艇ex_stが予定外（{1}）".format(i, ex_st_))

        else:
            raise Exception("{0}号艇ex_stが予定外（{1}）".format(i, ex_st_))
        
        # 最初に定義したリストに辞書型のデータを追加
        race_result_dict_list.append(race_result_dict)

    # dictを入れたlistをdfに変換
    beforeinfo_df = pd.DataFrame.from_dict(race_result_dict_list)

    time.sleep(0.1)

    return beforeinfo_df

# %%
def scrape_raceresult(soup, rno, jcd, hd):
    
    race_result_dict_list = []
    
    table = soup.find(class_="contentsFrame1_inner").find_all(class_="table1")[1]
    rows = table.find_all("tbody")
    
    for row in rows:
        race_result_dict = {"date": "-".join([hd[0:4], hd[5:7], hd[8:10]]),
                            "venue": jcd,
                            "raceNumber": rno[:-1]
                            }
        race_result_dict["着順"] = row.find_all("td")[0].text
        # 枠番はintegerにしておかないとconcatした時に別の行として扱われてしまう
        race_result_dict["枠"] = int(row.find_all("td")[1].text)
        race_result_dict["タイム"] = row.find_all("td")[3].text
        
        # 最初に定義したリストに辞書型のデータを追加
        race_result_dict_list.append(race_result_dict)
    
    # dictを入れたlistをdfに変換
    raceresult_df = pd.DataFrame.from_dict(race_result_dict_list)

    time.sleep(0.1)

    return raceresult_df

# %% [markdown]
# ### そのほかcrawl, scrapeに必要なモジュール

# %%
def make_url(crawl_key, rno, jcd, hd):
    """
    :param crawl_key: 何をcrawleするか。選択肢は、"odds3t"（オッズ）, "racelist"(出走表）,
    "beforeinfo" (直前情報）もしくは"raceresult" (レース結果)
    :param rno: レース番号。8Rなど、1-12の数字 + R をstrで
    :param jcd: 会場名。"桐　生"、"びわこ"など
    :param hd: holding day (レース開催日)、2019/03/28などyyyy/mm/ddの形で入力（strで）
    :return dds_url: 公式サイト最終オッズが書かれているページのurl. これを使ってcrawlする
    """
    jcd_dict =  {"桐　生": "01", "戸　田": "02", "江戸川": "03", "平和島": "04", "多摩川": "05", "浜名湖": "06", "蒲　郡": "07", "常　滑": "08",
                "　津　": "09", "三　国": "10", "びわこ": "11", "住之江": "12", "尼　崎": "13", "鳴　門": "14", "丸　亀": "15", "児　島": "16",
                "宮　島": "17", "徳　山": "18", "下　関": "19", "若　松": "20", "芦　屋": "21", "福　岡": "22", "唐　津": "23", "大　村": "24"
                }
    rno = rno[:-1]
    hd = hd[0:4] + hd[5:7] + hd[8:10]

    odds_url = "http://boatrace.jp/owpc/pc/race/" + crawl_key + "?rno=" + rno + "&jcd=" + jcd_dict[jcd] + "&hd=" + hd

    return odds_url


def html_parser(site_url):
    headers = {
        "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:47.0) Gecko/20100101 Firefox/47.0",
    }

    try:
        request = urllib.request.Request(url=site_url, headers=headers)
        response = urllib.request.urlopen(request)

        html = response.read().decode('utf-8')
        soup = BeautifulSoup(html, 'lxml')

    # データベース作成の際、remotedisconnectedになった場合,そのレースをパス
    except RemoteDisconnected:
        print("remote disconnected error !")
        return None

    except ConnectionResetError:
        print("Connection Reset error !")
        return None

    return soup

def get_extractor(crawl_key):
    
    """
    クロール先に応じたcrawlerを用意
    
    """
    
    extractor_dict = {"racelist": scrape_racelist,
                      "beforeinfo": scrape_beforeinfo,
                      "raceresult": scrape_raceresult,
                      }
    
    return extractor_dict[crawl_key]

# %% [markdown]
# ### 実行部分

# %%
crawl_key_list = ["racelist", "beforeinfo", "raceresult"]
jcd_list =  ["桐　生", "戸　田", "江戸川", "平和島", "多摩川", "浜名湖", "蒲　郡", "常　滑",
                "　津　", "三　国", "びわこ", "住之江", "尼　崎", "鳴　門", "丸　亀", "児　島",
                "宮　島", "徳　山", "下　関", "若　松", "芦　屋", "福　岡", "唐　津", "大　村"
            ]

hd = "2021/03/09"

# 1日単位でデータを集めてファイルに保存する
today_race_df_list = []

for jcd in jcd_list:
    for i in range(1, 13):
        rno = str(i) + "R"
        
        # その日レースがない場所は飛ばすためのtry-except         
        try:
            # 色々なkeyに対してクロールして特定のレースの情報がまとまったdfを作る
            race_info_df_list = []

            for crawl_key in crawl_key_list:
                raceResult_url = make_url(crawl_key, rno, jcd, hd)

                # パース
                soup = html_parser(raceResult_url)

                # extractorの指定
                the_extractor = get_extractor(crawl_key)

                # 対象サイトをcrawl
                race_information_df = the_extractor(soup, rno, jcd, hd)
                race_information_df = race_information_df.set_index(["date", "venue", "raceNumber", "枠"])

                race_info_df_list.append(race_information_df)

            this_race_df =pd.concat(race_info_df_list, axis=1, join_axes=[race_info_df_list[0].index])
            # 今回のレースのデータを本日のデータを集めたリストに格納
            today_race_df_list.append(this_race_df)
        
        except IndexError:
            print(hd + " " + jcd + rno +"データなし")
            pass
        
# 本日のレースデータを集めたリストをdfに変換    
today_race_df = pd.concat(today_race_df_list, axis = 0)

# pickleファイルで保存
today_race_df.to_pickle('./{0}.pkl'.format("".join(hd.split("/"))))
# Out:
# 2021/03/09 桐　生1Rデータなし
# 2021/03/09 桐　生2Rデータなし
# 2021/03/09 桐　生3Rデータなし
# 2021/03/09 桐　生4Rデータなし
# 2021/03/09 桐　生5Rデータなし
# 2021/03/09 桐　生6Rデータなし
# 2021/03/09 桐　生7Rデータなし
# 2021/03/09 桐　生8Rデータなし
# 2021/03/09 桐　生9Rデータなし
# 2021/03/09 桐　生10Rデータなし
# 2021/03/09 桐　生11Rデータなし
# 2021/03/09 桐　生12Rデータなし
# 2021/03/09 戸　田8Rデータなし
# 2021/03/09 江戸川1Rデータなし
# 2021/03/09 江戸川2Rデータなし
# 2021/03/09 江戸川3Rデータなし
# 2021/03/09 江戸川4Rデータなし
# 2021/03/09 江戸川5Rデータなし
# 2021/03/09 江戸川6Rデータなし
# 2021/03/09 江戸川7Rデータなし
# 2021/03/09 江戸川8Rデータなし
# 2021/03/09 江戸川9Rデータなし
# 2021/03/09 江戸川10Rデータなし
# 2021/03/09 江戸川11Rデータなし
# 2021/03/09 江戸川12Rデータなし
# 2021/03/09 平和島1Rデータなし
# 2021/03/09 平和島2Rデータなし
# 2021/03/09 平和島3Rデータなし
# 2021/03/09 平和島4Rデータなし
# 2021/03/09 平和島5Rデータなし
# 2021/03/09 平和島6Rデータなし
# 2021/03/09 平和島7Rデータなし
# 2021/03/09 平和島8Rデータなし
# 2021/03/09 平和島9Rデータなし
# 2021/03/09 平和島10Rデータなし
# 2021/03/09 平和島11Rデータなし
# 2021/03/09 平和島12Rデータなし
# 2021/03/09 浜名湖1Rデータなし
# 2021/03/09 浜名湖2Rデータなし
# 2021/03/09 浜名湖3Rデータなし
# 2021/03/09 浜名湖4Rデータなし
# 2021/03/09 浜名湖5Rデータなし
# 2021/03/09 浜名湖6Rデータなし
# 2021/03/09 浜名湖7Rデータなし
# 2021/03/09 浜名湖8Rデータなし
# 2021/03/09 浜名湖9Rデータなし
# 2021/03/09 浜名湖10Rデータなし
# 2021/03/09 浜名湖11Rデータなし
# 2021/03/09 浜名湖12Rデータなし
# 2021/03/09 蒲　郡1Rデータなし
# 2021/03/09 蒲　郡2Rデータなし
# 2021/03/09 蒲　郡3Rデータなし
# 2021/03/09 蒲　郡4Rデータなし
# 2021/03/09 蒲　郡5Rデータなし
# 2021/03/09 蒲　郡6Rデータなし
# 2021/03/09 蒲　郡7Rデータなし
# 2021/03/09 蒲　郡8Rデータなし
# 2021/03/09 蒲　郡9Rデータなし
# 2021/03/09 蒲　郡10Rデータなし
# 2021/03/09 蒲　郡11Rデータなし
# 2021/03/09 蒲　郡12Rデータなし
# 2021/03/09 常　滑12Rデータなし
# 2021/03/09 　津　1Rデータなし
# 2021/03/09 　津　2Rデータなし
# 2021/03/09 　津　3Rデータなし
# 2021/03/09 　津　4Rデータなし
# 2021/03/09 　津　5Rデータなし
# 2021/03/09 　津　6Rデータなし
# 2021/03/09 　津　7Rデータなし
# 2021/03/09 　津　8Rデータなし
# 2021/03/09 　津　9Rデータなし
# 2021/03/09 　津　10Rデータなし
# 2021/03/09 　津　11Rデータなし
# 2021/03/09 　津　12Rデータなし
# 2021/03/09 三　国1Rデータなし
# 2021/03/09 三　国2Rデータなし
# 2021/03/09 三　国3Rデータなし
# 2021/03/09 三　国4Rデータなし
# 2021/03/09 三　国5Rデータなし
# 2021/03/09 三　国6Rデータなし
# 2021/03/09 三　国7Rデータなし
# 2021/03/09 三　国8Rデータなし
# 2021/03/09 三　国9Rデータなし
# 2021/03/09 三　国10Rデータなし
# 2021/03/09 三　国11Rデータなし
# 2021/03/09 三　国12Rデータなし
# 2021/03/09 びわこ1Rデータなし
# 2021/03/09 びわこ2Rデータなし
# 2021/03/09 びわこ3Rデータなし
# 2021/03/09 びわこ4Rデータなし
# 2021/03/09 びわこ5Rデータなし
# 2021/03/09 びわこ6Rデータなし
# 2021/03/09 びわこ7Rデータなし
# 2021/03/09 びわこ8Rデータなし
# 2021/03/09 びわこ9Rデータなし
# 2021/03/09 びわこ10Rデータなし
# 2021/03/09 びわこ11Rデータなし
# 2021/03/09 びわこ12Rデータなし
# 2021/03/09 尼　崎1Rデータなし
# 2021/03/09 尼　崎2Rデータなし
# 2021/03/09 尼　崎3Rデータなし
# 2021/03/09 尼　崎4Rデータなし
# 2021/03/09 尼　崎5Rデータなし
# 2021/03/09 尼　崎6Rデータなし
# 2021/03/09 尼　崎7Rデータなし
# 2021/03/09 尼　崎8Rデータなし
# 2021/03/09 尼　崎9Rデータなし
# 2021/03/09 尼　崎10Rデータなし
# 2021/03/09 尼　崎11Rデータなし
# 2021/03/09 尼　崎12Rデータなし
# 2021/03/09 鳴　門1Rデータなし
# 2021/03/09 鳴　門2Rデータなし
# 2021/03/09 鳴　門3Rデータなし
# 2021/03/09 鳴　門4Rデータなし
# 2021/03/09 鳴　門5Rデータなし
# 2021/03/09 鳴　門6Rデータなし
# 2021/03/09 鳴　門7Rデータなし
# 2021/03/09 鳴　門8Rデータなし
# 2021/03/09 鳴　門9Rデータなし
# 2021/03/09 鳴　門10Rデータなし
# 2021/03/09 鳴　門11Rデータなし
# 2021/03/09 鳴　門12Rデータなし
# 2021/03/09 宮　島1Rデータなし
# 2021/03/09 宮　島2Rデータなし
# 2021/03/09 宮　島3Rデータなし
# 2021/03/09 宮　島4Rデータなし
# 2021/03/09 宮　島5Rデータなし
# 2021/03/09 宮　島6Rデータなし
# 2021/03/09 宮　島7Rデータなし
# 2021/03/09 宮　島8Rデータなし
# 2021/03/09 宮　島9Rデータなし
# 2021/03/09 宮　島10Rデータなし
# 2021/03/09 宮　島11Rデータなし
# 2021/03/09 宮　島12Rデータなし
# 2021/03/09 徳　山8Rデータなし
# 2021/03/09 下　関1Rデータなし
# 2021/03/09 下　関2Rデータなし
# 2021/03/09 下　関3Rデータなし
# 2021/03/09 下　関4Rデータなし
# 2021/03/09 下　関5Rデータなし
# 2021/03/09 下　関6Rデータなし
# 2021/03/09 下　関7Rデータなし
# 2021/03/09 下　関8Rデータなし
# 2021/03/09 下　関9Rデータなし
# 2021/03/09 下　関10Rデータなし
# 2021/03/09 下　関11Rデータなし
# 2021/03/09 下　関12Rデータなし
# 2021/03/09 若　松1Rデータなし
# 2021/03/09 若　松2Rデータなし
# 2021/03/09 若　松3Rデータなし
# 2021/03/09 若　松4Rデータなし
# 2021/03/09 若　松5Rデータなし
# 2021/03/09 若　松6Rデータなし
# 2021/03/09 若　松7Rデータなし
# 2021/03/09 若　松8Rデータなし
# 2021/03/09 若　松9Rデータなし
# 2021/03/09 若　松10Rデータなし
# 2021/03/09 若　松11Rデータなし
# 2021/03/09 若　松12Rデータなし
# 2021/03/09 唐　津1Rデータなし
# 2021/03/09 唐　津2Rデータなし
# 2021/03/09 唐　津3Rデータなし
# 2021/03/09 唐　津4Rデータなし
# 2021/03/09 唐　津5Rデータなし
# 2021/03/09 唐　津6Rデータなし
# 2021/03/09 唐　津7Rデータなし
# 2021/03/09 唐　津8Rデータなし
# 2021/03/09 唐　津9Rデータなし
# 2021/03/09 唐　津10Rデータなし
# 2021/03/09 唐　津11Rデータなし
# 2021/03/09 唐　津12Rデータなし
# 2021/03/09 大　村4Rデータなし
# 2021/03/09 大　村6Rデータなし
# 2021/03/09 大　村11Rデータなし

# %%
# ファイル内容確認用
pd.read_pickle('./{0}.pkl'.format("".join(hd.split("/"))))
# Out:
#                               boatNo motorNo num_false_start num_late_start  \
# date       venue raceNumber 枠
# 2021-03-09 戸　田   1          1     35      30              F0             L0
#                             2     72      48              F0             L0
#                             3     25       1              F0             L0
#                             4     61      53              F0             L0
#                             5     27      25              F0             L0
#                             6     37      20              F0             L0
#                  2          1     65      65              F0             L0
#                             2     15      36              F0             L0
#                             3     50      47              F0             L0
#                             4     67      16              F1             L0
#                             5     55      15              F0             L0
#                             6     70      64              F0             L0
#                  3          1     75       4              F0             L0
#                             2     68      31              F0             L0
#                             3     32      63              F0             L0
#                             4     34       5              F0             L0
#                             5     66      18              F0             L0
#                             6     59       6              F0             L0
#                  4          1     62      52              F0             L0
#                             2     54      51              F0             L0
#                             3     20       3              F0             L0
#                             4     19      22              F0             L0
#                             5     22      60              F0             L0
#                             6     74      13              F0             L0
#                  5          1     41      24              F0             L0
#                             2     42      57              F0             L0
#                             3     72      48              F0             L0
#                             4     57      44              F0             L0
#                             5     21      43              F0             L0
#                             6     43       8              F0             L0
# ...                              ...     ...             ...            ...
#            大　村   7          1     25      44              F0             L0
#                             2     70      28              F0             L0
#                             3     61      40              F0             L0
#                             4     62      54              F0             L0
#                             5     67      39              F0             L0
#                             6     17      32              F0             L0
#                  8          1     57      58              F0             L0
#                             2     58      64              F0             L0
#                             3     63      72              F0             L0
#                             4     37      63              F0             L0
#                             5     29      17              F0             L0
#                             6     28      19              F0             L0
#                  9          1     46      33              F0             L0
#                             2     56      24              F1             L0
#                             3     14      65              F0             L0
#                             4     35      34              F1             L0
#                             5     73      52              F0             L0
#                             6     49      66              F1             L0
#                  10         1     70      28              F0             L0
#                             2     65      31              F0             L0
#                             3     13      37              F0             L0
#                             4     38      47              F0             L0
#                             5     34      22              F0             L0
#                             6     64      27              F0             L0
#                  12         1     58      64              F0             L0
#                             2     62      54              F0             L0
#                             3     24      74              F0             L0
#                             4     46      33              F0             L0
#                             5     21      13              F0             L0
#                             6     44      75              F0             L0
#
#                               racer_id racer_name  ボート2連率  ボート3連率 モーター2連率  \
# date       venue raceNumber 枠
# 2021-03-09 戸　田   1          1     3778     安達　　美帆   41.98   54.96   34.64
#                             2     4901     出口　舞有子   36.50   53.28   45.88
#                             3     4678     水野　　望美   42.42   57.58   36.60
#                             4     5072     吉田　　杏美   30.71   46.43   34.03
#                             5     4088     野田　　祥子   34.75   51.77   32.87
#                             6     5174     川井　　　萌   31.91   51.77   33.55
#                  2          1     3528     笠野　友紀恵   31.72   46.21   42.75
#                             2     4845     前田　　紗希   39.42   61.31   33.33
#                             3     4746     大豆生田　蒼   35.42   47.22   30.72
#                             4     3900     香川　　素子   31.72   55.17   33.73
#                             5     5123     福山　恵里奈   33.88   49.59   37.18
#                             6     5151     山下　　奈緒   31.72   48.28   44.30
#                  3          1     3207     田村　　美和   32.14   42.86   29.67
#                             2     4730     土屋　実沙希   34.06   60.14   39.76
#                             3     4443     津田　　裕絵   37.24   53.10   42.36
#                             4     4546     浜田　亜理沙   41.61   56.20   41.57
#                             5     5088     高憧　　四季   38.19   54.17   34.29
#                             6     4556     竹井　　奈美   38.62   51.72   33.33
#                  4          1     4823     中村　　桃佳   36.80   52.80   34.46
#                             2     4399     松本　　晶恵   35.46   50.35   32.88
#                             3     5045     平川　　香織   35.97   53.96   38.78
#                             4     4183     宇野　　弥生   39.01   51.06   42.94
#                             5     4927     関野　　　文   33.33   52.48   32.19
#                             6     4225     土屋　　千明   37.19   55.37   32.00
#                  5          1     4738     清埜　　翔子   30.22   46.04   30.97
#                             2     4433     川野　　芽唯   37.84   50.68   47.88
#                             3     4901     出口　舞有子   36.50   53.28   45.88
#                             4     4900     中田　　夕貴   37.50   56.25   32.89
#                             5     4313     西村　美智子   38.41   56.52   34.48
#                             6     4117     廣中　智紗衣   32.14   45.71   31.03
# ...                                ...        ...     ...     ...     ...
#            大　村   7          1     4553     坪口　　竜也   38.18   55.76   27.11
#                             2     4184     渡邊　雄一郎   35.19   46.91   28.57
#                             3     3755     吉村　　和也   40.49   54.60   23.35
#                             4     3514     山一　　鉄也   32.93   48.78   27.16
#                             5     4403     木下　　大將   39.88   53.99   32.94
#                             6     5138     村本　　大成   40.25   55.35   26.88
#                  8          1     3968     茶谷　　信次   31.71   52.44   45.68
#                             2     3961     谷村　　一哉   35.37   49.39   32.00
#                             3     4099     吉永　　則雄   30.57   48.41   45.45
#                             4     3975     小野寺　智洋   37.35   51.81   28.99
#                             5     3627     井上　　恵一   36.88   55.63   31.10
#                             6     4220     深川　　和仁   37.09   53.64   30.06
#                  9          1     4361     柳生　　泰二   32.14   52.38   30.72
#                             2     4533     峰重　　侑治   31.37   49.67   28.22
#                             3     3873     別府　　昌樹   26.67   40.00   28.00
#                             4     4552     杉山　　勝匡   48.17   60.37   31.10
#                             5     3703     鳥飼　　　眞   33.33   56.17   32.73
#                             6     3290     倉谷　　和信   38.18   58.18   31.01
#                  10         1     4184     渡邊　雄一郎   35.19   46.91   28.57
#                             2     4359     横川　　聖志   30.92   48.03   26.85
#                             3     4584     村岡　　賢人   30.86   40.12   36.84
#                             4     4543     重木　　輝彦   27.06   47.65   26.62
#                             5     3881     浦上　　拓也   27.45   43.79   36.54
#                             6     3615     横田　　　茂   30.77   57.05   39.13
#                  12         1     3961     谷村　　一哉   35.37   49.39   32.00
#                             2     3514     山一　　鉄也   32.93   48.78   27.16
#                             3     3920     正木　　聖賢   24.49   39.46   26.11
#                             4     4361     柳生　　泰二   32.14   52.38   30.72
#                             5     3462     竹上　　真司   36.69   55.62   41.72
#                             6     4649     和田　　操拓   29.94   45.86   50.34
#
#                               モーター3連率 ... late temperature  tilt  \
# date       venue raceNumber 枠         ...
# 2021-03-09 戸　田   1          1   45.75 ...    0        13.0  -0.5
#                             2   61.76 ...    0        13.0  -0.5
#                             3   60.78 ...    0        13.0  -0.5
#                             4   50.00 ...    0        13.0  -0.5
#                             5   54.55 ...    0        13.0  -0.5
#                             6   47.74 ...    0        13.0  -0.5
#                  2          1   64.49 ...    0         9.0  -0.5
#                             2   51.02 ...    0         9.0  -0.5
#                             3   44.44 ...    0         9.0  -0.5
#                             4   56.21 ...    0         9.0  -0.5
#                             5   50.64 ...    0         9.0  -0.5
#                             6   64.43 ...    0         9.0  -0.5
#                  3          1   41.76 ...    0        10.0  -0.5
#                             2   62.05 ...    0        10.0  -0.5
#                             3   54.17 ...    0        10.0  -0.5
#                             4   62.92 ...    0        10.0  -0.5
#                             5   57.14 ...    0        10.0  -0.5
#                             6   49.66 ...    0        10.0  -0.5
#                  4          1   50.00 ...    0        10.0  -0.5
#                             2   43.84 ...    0        10.0  -0.5
#                             3   51.70 ...    0        10.0  -0.5
#                             4   58.82 ...    0        10.0  -0.5
#                             5   47.95 ...    0        10.0  -0.5
#                             6   48.00 ...    0        10.0  -0.5
#                  5          1   42.48 ...    0        11.0  -0.5
#                             2   64.24 ...    0        11.0  -0.5
#                             3   61.76 ...    0        11.0  -0.5
#                             4   52.63 ...    0        11.0  -0.5
#                             5   46.90 ...    0        11.0  -0.5
#                             6   48.28 ...    0        11.0  -0.5
# ...                               ... ...  ...         ...   ...
#            大　村   7          1   46.99 ...    0        16.0   0.0
#                             2   43.51 ...    0        16.0  -0.5
#                             3   43.11 ...    0        16.0  -0.5
#                             4   38.89 ...    0        16.0  -0.5
#                             5   52.35 ...    0        16.0  -0.5
#                             6   48.75 ...    0        16.0  -0.5
#                  8          1   61.11 ...    0        16.0  -0.5
#                             2   51.43 ...    0        16.0  -0.5
#                             3   58.79 ...    0        16.0  -0.5
#                             4   42.01 ...    0        16.0  -0.5
#                             5   43.29 ...    0        16.0  -0.5
#                             6   47.85 ...    0        16.0  -0.5
#                  9          1   45.78 ...    0        14.0  -0.5
#                             2   41.72 ...    0        14.0  -0.5
#                             3   44.67 ...    0        14.0  -0.5
#                             4   45.73 ...    0        14.0  -0.5
#                             5   51.52 ...    0        14.0  -0.5
#                             6   46.20 ...    0        14.0  -0.5
#                  10         1   43.51 ...    0        14.0  -0.5
#                             2   44.30 ...    0        14.0  -0.5
#                             3   50.88 ...    0        14.0  -0.5
#                             4   42.86 ...    0        14.0   0.0
#                             5   54.49 ...    0        14.0  -0.5
#                             6   52.17 ...    0        14.0  -0.5
#                  12         1   51.43 ...    0        13.0  -0.5
#                             2   38.89 ...    0        13.0  -0.5
#                             3   44.59 ...    0        13.0  -0.5
#                             4   45.78 ...    0        13.0  -0.5
#                             5   52.15 ...    0        13.0  -0.5
#                             6   66.67 ...    0        13.0  -0.5
#
#                                water_temperature  wave_height weather weight  \
# date       venue raceNumber 枠
# 2021-03-09 戸　田   1          1                9.0            1      曇り   46.5
#                             2                9.0            1      曇り   46.5
#                             3                9.0            1      曇り   45.5
#                             4                9.0            1      曇り   49.5
#                             5                9.0            1      曇り   48.4
#                             6                9.0            1      曇り   45.0
#                  2          1                9.0            0       晴   48.4
#                             2                9.0            0       晴   48.1
#                             3                9.0            0       晴   47.0
#                             4                9.0            0       晴   47.0
#                             5                9.0            0       晴   47.1
#                             6                9.0            0       晴   49.0
#                  3          1                9.0            0       晴   51.2
#                             2                9.0            0       晴   46.5
#                             3                9.0            0       晴   49.0
#                             4                9.0            0       晴   47.0
#                             5                9.0            0       晴   46.0
#                             6                9.0            0       晴   47.0
#                  4          1                9.0            0       晴   46.0
#                             2                9.0            0       晴   47.0
#                             3                9.0            0       晴   47.0
#                             4                9.0            0       晴   47.3
#                             5                9.0            0       晴   45.5
#                             6                9.0            0       晴   46.5
#                  5          1                9.0            0       晴   47.0
#                             2                9.0            0       晴   47.0
#                             3                9.0            0       晴   46.5
#                             4                9.0            0       晴   47.1
#                             5                9.0            0       晴   47.5
#                             6                9.0            0       晴   46.0
# ...                                          ...          ...     ...    ...
#            大　村   7          1               11.0            1       晴   52.6
#                             2               11.0            1       晴   50.5
#                             3               11.0            1       晴   50.5
#                             4               11.0            1       晴   52.0
#                             5               11.0            1       晴   51.5
#                             6               11.0            1       晴   53.9
#                  8          1               11.0            1       晴   52.0
#                             2               11.0            1       晴   54.1
#                             3               11.0            1       晴   52.0
#                             4               11.0            1       晴   51.5
#                             5               11.0            1       晴   52.2
#                             6               11.0            1       晴   52.0
#                  9          1               10.0            1       晴   52.4
#                             2               10.0            1       晴   51.5
#                             3               10.0            1       晴   52.0
#                             4               10.0            1       晴   51.5
#                             5               10.0            1       晴   50.5
#                             6               10.0            1       晴   53.1
#                  10         1               10.0            2       晴   50.5
#                             2               10.0            2       晴   54.2
#                             3               10.0            2       晴   52.3
#                             4               10.0            2       晴   50.0
#                             5               10.0            2       晴   52.0
#                             6               10.0            2       晴   51.5
#                  12         1               10.0            2       晴   54.1
#                             2               10.0            2       晴   52.0
#                             3               10.0            2       晴   52.1
#                             4               10.0            2       晴   52.4
#                             5               10.0            2       晴   51.5
#                             6               10.0            2       晴   52.0
#
#                               wind_speed     タイム 着順
# date       venue raceNumber 枠
# 2021-03-09 戸　田   1          1          2          ５
#                             2          2  1'49"1  １
#                             3          2  1'49"4  ２
#                             4          2  1'54"8  ４
#                             5          2  1'52"7  ３
#                             6          2          ６
#                  2          1          0  1'50"9  ３
#                             2          0  1'53"5  ４
#                             3          0  1'48"7  １
#                             4          0  1'50"3  ２
#                             5          0          ６
#                             6          0          ５
#                  3          1          0          ５
#                             2          0          ６
#                             3          0  1'51"2  ３
#                             4          0  1'48"5  ２
#                             5          0  1'53"2  ４
#                             6          0  1'47"5  １
#                  4          1          0  1'49"9  ２
#                             2          0  1'52"6  ４
#                             3          0          ６
#                             4          0  1'48"5  １
#                             5          0  1'52"4  ３
#                             6          0          ５
#                  5          1          0  1'48"4  １
#                             2          0  1'50"0  ２
#                             3          0          ６
#                             4          0  1'52"7  ４
#                             5          0  1'52"2  ３
#                             6          0          ５
# ...                                  ...     ... ..
#            大　村   7          1          1  1'48"6  １
#                             2          1  1'50"1  ２
#                             3          1  1'51"7  ４
#                             4          1          ５
#                             5          1  1'51"5  ３
#                             6          1          ６
#                  8          1          1  1'48"0  １
#                             2          1          ６
#                             3          1  1'49"2  ２
#                             4          1  1'51"9  ４
#                             5          1  1'51"5  ３
#                             6          1          ５
#                  9          1          2  1'52"4  ３
#                             2          2          ６
#                             3          2  1'50"9  ２
#                             4          2          ５
#                             5          2  1'49"6  １
#                             6          2  1'53"0  ４
#                  10         1          3  1'49"2  ２
#                             2          3          ５
#                             3          3  1'48"0  １
#                             4          3  1'51"4  ３
#                             5          3  1'53"1  ４
#                             6          3          ６
#                  12         1          3  1'48"5  １
#                             2          3  1'53"5  ４
#                             3          3          ５
#                             4          3  1'50"3  ２
#                             5          3  1'51"8  ３
#                             6          3          ６
#
# [684 rows x 24 columns]
